# %% [markdown]
# # Telco Customer Churn Challenge
#
# Useful resources:
#   - `Theory.pdf`;
#   - Central Limit Theorem Visualization: http://mfviz.com/central-limit/;
#   - Standard Deviation: https://en.wikipedia.org/wiki/Standard_deviation.
#
# ---
#
# The [Bias-Variance Tradeoff](https://en.wikipedia.org/wiki/Bias%E2%80%93variance_tradeoff)
#
# We can reason about them as follows:
#
# - bias: how "dumb" the model is;
# - variance: how uncertain the model is.
#
# <img src='https://raw.githubusercontent.com/SimeonHristov99/ML_23-24/main/assets/BiasVarianceTradeoff.png'>
#
# Bias and variance as function of model complexity:
#
# <img src='https://upload.wikimedia.org/wikipedia/commons/9/9f/Bias_and_variance_contributing_to_total_error.svg'>
#
# ---
#
# - Type of problem trees and forests can solve: Classification and Regression
# - Do trees require scaling of the data? No.
# - Goal: Predict whether a customer will churn.

# %% [markdown]
# ## Imports and Constants

# %% [markdown]
# # Task 1

# %% [markdown]
# > Note: Most likely you don't have the package `xgboost` installed. You can install it with Python's package manager - `pip`:
#
# ```console
# pip install xgboost
# ```

# %%
# Add magic command to delete all saved variables
# %reset -f

# %%
# Imports and constant values here
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Get the data

# %%
# Load and display the `Telco-Customer-Churn.csv` file from the GitHub repo and save it in a dataframe `df_churn`.
df_churn = pd.read_csv('https://raw.githubusercontent.com/SimeonHristov99/ML_23-24/main/DATA/Telco-Customer-Churn.csv')
df_churn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7027  6840-RESVB    Male              0     Yes        Yes      24
# 7028  2234-XADUH  Female              0     Yes        Yes      72
# 7029  4801-JZAZL  Female              0     Yes        Yes      11
# 7030  8361-LTMKD    Male              1     Yes         No       4
# 7031  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7027          Yes               Yes             DSL            Yes  ...
# 7028          Yes               Yes     Fiber optic             No  ...
# 7029           No  No phone service             DSL            Yes  ...
# 7030          Yes               Yes     Fiber optic             No  ...
# 7031          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7027              Yes         Yes         Yes             Yes        One year
# 7028              Yes          No         Yes             Yes        One year
# 7029               No          No          No              No  Month-to-month
# 7030               No          No          No              No  Month-to-month
# 7031              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95       1889.50
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7027              Yes               Mailed check          84.80       1990.50
# 7028              Yes    Credit card (automatic)         103.20       7362.90
# 7029              Yes           Electronic check          29.60        346.45
# 7030              Yes               Mailed check          74.40        306.60
# 7031              Yes  Bank transfer (automatic)         105.65       6844.50
#
#       Churn
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
# ...     ...
# 7027     No
# 7028     No
# 7029     No
# 7030    Yes
# 7031     No
#
# [7032 rows x 21 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Display a summary of the features.
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
#  16  PaperlessBilling  7032 non-null   object
#  17  PaymentMethod     7032 non-null   object
#  18  MonthlyCharges    7032 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7032 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
# Display summary statistics. What do you see?
df_churn.describe().T
# Out:
#                  count         mean          std    min       25%       50%  \
# SeniorCitizen   7032.0     0.162400     0.368844   0.00    0.0000     0.000
# tenure          7032.0    32.421786    24.545260   1.00    9.0000    29.000
# MonthlyCharges  7032.0    64.798208    30.085974  18.25   35.5875    70.350
# TotalCharges    7032.0  2283.300441  2266.771362  18.80  401.4500  1397.475
#
#                       75%      max
# SeniorCitizen      0.0000     1.00
# tenure            55.0000    72.00
# MonthlyCharges    89.8625   118.75
# TotalCharges    3794.7375  8684.80

# %%
# Show the statistics for the non-numeric features. What do you see?
df_churn.select_dtypes(['object']).describe().T
# Out:
#                  count unique               top  freq
# customerID        7032   7032        7590-VHVEG     1
# gender            7032      2              Male  3549
# Partner           7032      2                No  3639
# Dependents        7032      2                No  4933
# PhoneService      7032      2               Yes  6352
# MultipleLines     7032      3                No  3385
# InternetService   7032      3       Fiber optic  3096
# OnlineSecurity    7032      3                No  3497
# OnlineBackup      7032      3                No  3087
# DeviceProtection  7032      3                No  3094
# TechSupport       7032      3                No  3472
# StreamingTV       7032      3                No  2809
# StreamingMovies   7032      3                No  2781
# Contract          7032      3    Month-to-month  3875
# PaperlessBilling  7032      2               Yes  4168
# PaymentMethod     7032      4  Electronic check  2365
# Churn             7032      2                No  5163

# %% [markdown]
# I am not sure what I am supposed to see, but I can tell that most of the non-numeric features are actually boolean features that hide behind a yes/no string.

# %%
# Are there any missing values?
df_churn.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Check the distribution of the target variable. What are the conclusions?
df_churn['Churn'].value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# The conclusion is that the target variable isn't balanced and we need to account for that.

# %%
# Output the unique values. If they are less than 12, print them.
# Your output needn't match exactly.
# What do you see?
for col in df_churn:
  unq_vals = df_churn[col].unique()
  num_unq_vals = len(unq_vals)
  
  if num_unq_vals < 12:
    print(f'Unique {col:17} | {df_churn[col].dtype} | {num_unq_vals:5} | {unq_vals}')
  else:
    print(f'Unique {col:17} | {df_churn[col].dtype} | {num_unq_vals:5} |')
# Out:
# Unique customerID        | object |  7032 |
# Unique gender            | object |     2 | ['Female' 'Male']
# Unique SeniorCitizen     | int64 |     2 | [0 1]
# Unique Partner           | object |     2 | ['Yes' 'No']
# Unique Dependents        | object |     2 | ['No' 'Yes']
# Unique tenure            | int64 |    72 |
# Unique PhoneService      | object |     2 | ['No' 'Yes']
# Unique MultipleLines     | object |     3 | ['No phone service' 'No' 'Yes']
# Unique InternetService   | object |     3 | ['DSL' 'Fiber optic' 'No']
# Unique OnlineSecurity    | object |     3 | ['No' 'Yes' 'No internet service']
# Unique OnlineBackup      | object |     3 | ['Yes' 'No' 'No internet service']
# Unique DeviceProtection  | object |     3 | ['No' 'Yes' 'No internet service']
# Unique TechSupport       | object |     3 | ['No' 'Yes' 'No internet service']
# Unique StreamingTV       | object |     3 | ['No' 'Yes' 'No internet service']
# Unique StreamingMovies   | object |     3 | ['No' 'Yes' 'No internet service']
# Unique Contract          | object |     3 | ['Month-to-month' 'One year' 'Two year']
# Unique PaperlessBilling  | object |     2 | ['Yes' 'No']
# Unique PaymentMethod     | object |     4 | ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Unique MonthlyCharges    | float64 |  1584 |
# Unique TotalCharges      | float64 |  6530 |
# Unique Churn             | object |     2 | ['No' 'Yes']

# %% [markdown]
# We can see that there are problematic values, such as 'No' and 'No phone service' which mean the same thing.

# %%
# Plot the distribution of the `TotalCharges` column.
sns.histplot(df_churn['TotalCharges']);

# %%
# Show relationships between numeric features and the target column.
# Create a table of the proper numeric features.
numeric_features = df_churn[['tenure', 'MonthlyCharges', 'TotalCharges', 'Churn']]
numeric_features
# Out:
#       tenure  MonthlyCharges  TotalCharges Churn
# 0          1           29.85         29.85    No
# 1         34           56.95       1889.50    No
# 2          2           53.85        108.15   Yes
# 3         45           42.30       1840.75    No
# 4          2           70.70        151.65   Yes
# ...      ...             ...           ...   ...
# 7027      24           84.80       1990.50    No
# 7028      72          103.20       7362.90    No
# 7029      11           29.60        346.45    No
# 7030       4           74.40        306.60   Yes
# 7031      66          105.65       6844.50    No
#
# [7032 rows x 4 columns]

# %%
# and then use `sns.pairplot` to visualize the relationships.
# What do you see?
sns.pairplot(numeric_features, hue='Churn')

# %%
# Show relationships between categorical features and the target column.
# Get a list of them first.
cat_features = df_churn.select_dtypes('object').columns.drop(['customerID', 'Churn'])
cat_features
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod'],
#       dtype='object')

# %%
# Then use the below code to visualize the relationship.
# What do you see?

for col in cat_features:
  fig, ax = plt.subplots(1,2)
  ax1 = sns.histplot(data=df_churn, x=col, hue="Churn", stat="probability", multiple="dodge", shrink=.8, ax=ax[0])
  ax2 = sns.histplot(data=df_churn, x=col, hue="Churn", stat="probability", multiple="fill", shrink=.8, ax=ax[1])
  fig.show()
# Out:
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_23634/1860085437.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Create a `preprocess_inputs` function that takes a dataframe and performs the following operations on it:
# - drops the `customerID` column. Can you answer why?
# - one-hot encodes categorical features. *Hint: see `pd.get_dummies`.*
# - splits the data into `X` and `y`;
# - Label-encodes the target column for easier interpretation (1 meaning 'Yes' and 0 meaning 'No');
# - performs a train-test split, keeping 30% of the data for testing.

# %%
def preprocess_inputs(df : pd.DataFrame) -> pd.DataFrame:
    df = df.drop(columns=['customerID'])
    
    return df
    
preprocess_inputs(df_churn)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7027    Male              0     Yes        Yes      24          Yes
# 7028  Female              0     Yes        Yes      72          Yes
# 7029  Female              0     Yes        Yes      11           No
# 7030    Male              1     Yes         No       4          Yes
# 7031    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7027               Yes             DSL            Yes           No
# 7028               Yes     Fiber optic             No          Yes
# 7029  No phone service             DSL            Yes           No
# 7030               Yes     Fiber optic             No           No
# 7031                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7027              Yes         Yes         Yes             Yes        One year
# 7028              Yes          No         Yes             Yes        One year
# 7029               No          No          No              No  Month-to-month
# 7030               No          No          No              No  Month-to-month
# 7031              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 2                 Yes               Mailed check           53.85
# 3                  No  Bank transfer (automatic)           42.30
# 4                 Yes           Electronic check           70.70
# ...               ...                        ...             ...
# 7027              Yes               Mailed check           84.80
# 7028              Yes    Credit card (automatic)          103.20
# 7029              Yes           Electronic check           29.60
# 7030              Yes               Mailed check           74.40
# 7031              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 2           108.15   Yes
# 3          1840.75    No
# 4           151.65   Yes
# ...            ...   ...
# 7027       1990.50    No
# 7028       7362.90    No
# 7029        346.45    No
# 7030        306.60   Yes
# 7031       6844.50    No
#
# [7032 rows x 20 columns]

# %% [markdown]
# <img src='https://raw.githubusercontent.com/SimeonHristov99/ML_23-24/main/assets/ohe.png'>

# %%
# Display X_train
# Out:
#       tenure  MonthlyCharges  TotalCharges  gender_Female  SeniorCitizen_0  \
# 2351      46           45.20       2065.15          False             True
# 4025      68           84.65       5683.60          False            False
# 4354      29           58.75       1696.20          False             True
# 5240      72           67.20       4671.70          False             True
# 4019      72          114.30       8058.55          False             True
# ...      ...             ...           ...            ...              ...
# 175       34           24.70        780.20           True             True
# 123        7           50.70        350.35           True             True
# 1321       1           69.25         69.25           True            False
# 2538      13           98.15       1230.25          False             True
# 3465      35           21.10        741.00           True             True
#
#       Partner_No  Dependents_No  PhoneService_No  PaperlessBilling_No  \
# 2351        True           True            False                False
# 4025       False          False            False                False
# 4354        True           True            False                False
# 5240        True          False             True                 True
# 4019       False          False            False                False
# ...          ...            ...              ...                  ...
# 175        False           True            False                 True
# 123        False          False            False                 True
# 1321        True           True            False                False
# 2538        True           True            False                 True
# 3465        True           True            False                 True
#
#       MultipleLines_No  ...  StreamingMovies_No  \
# 2351              True  ...                True
# 4025             False  ...                True
# 4354              True  ...                True
# 5240             False  ...               False
# 4019             False  ...               False
# ...                ...  ...                 ...
# 175              False  ...               False
# 123               True  ...                True
# 1321              True  ...                True
# 2538             False  ...               False
# 3465              True  ...               False
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 2351                                False                False
# 4025                                False                False
# 4354                                False                False
# 5240                                False                 True
# 4019                                False                 True
# ...                                   ...                  ...
# 175                                  True                False
# 123                                 False                False
# 1321                                False                False
# 2538                                False                 True
# 3465                                 True                False
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 2351                     True              False              False
# 4025                     True              False              False
# 4354                    False               True              False
# 5240                    False              False               True
# 4019                    False              False               True
# ...                       ...                ...                ...
# 175                      True              False              False
# 123                      True              False              False
# 1321                     True              False              False
# 2538                     True              False              False
# 3465                    False               True              False
#
#       PaymentMethod_Bank transfer (automatic)  \
# 2351                                    False
# 4025                                    False
# 4354                                    False
# 5240                                    False
# 4019                                    False
# ...                                       ...
# 175                                     False
# 123                                     False
# 1321                                    False
# 2538                                    False
# 3465                                    False
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 2351                                   True                           False
# 4025                                  False                            True
# 4354                                  False                            True
# 5240                                   True                           False
# 4019                                   True                           False
# ...                                     ...                             ...
# 175                                   False                            True
# 123                                   False                           False
# 1321                                  False                            True
# 2538                                  False                           False
# 3465                                  False                           False
#
#       PaymentMethod_Mailed check
# 2351                       False
# 4025                       False
# 4354                       False
# 5240                       False
# 4019                       False
# ...                          ...
# 175                        False
# 123                         True
# 1321                       False
# 2538                        True
# 3465                        True
#
# [4922 rows x 40 columns]

# %%
# Display y_train
# Out:
# 2351    0
# 4025    0
# 4354    0
# 5240    0
# 4019    0
#        ..
# 175     0
# 123     0
# 1321    1
# 2538    1
# 3465    0
# Name: Churn, Length: 4922, dtype: int64

# %% [markdown]
# # Task 3

# %% [markdown]
# ## Model building

# %%
# Create the `results` table - "df_results".
# Out:
# Empty DataFrame
# Columns: [experiment, accuracy, precision, recall, f1-score]
# Index: []

# %% [markdown]
# ### Decision Tree

# %%
# Train a DecisionTreeClassifier() with default parameters and evaluate it.
# Show "df_results" (output may vary because of randomness).
# Out:
# C:\Users\c86608b\AppData\Local\Temp\1\ipykernel_3984\146028450.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_results = pd.concat([df_results, pd.DataFrame({
#                    experiment  accuracy  precision    recall  f1-score  \
# 0  decision_tree_default_args  0.700948   0.456559  0.462069  0.459297
#
#     log_loss
# 0  10.778931

# %%
# Train a DecisionTreeClassifier() with a maximum depth of 3 and evaluate it.
# Show "df_results" (output may vary because of randomness).
# Out:
#                    experiment  accuracy  precision    recall  f1-score  \
# 0  decision_tree_default_args  0.700948   0.456559  0.462069  0.459297
# 1   decision_tree_max_depth_3  0.786730   0.718121  0.368966  0.487472
#
#     log_loss
# 0  10.778931
# 1   7.687035

# %%
# Use the sklearn.tree.plot_tree function to display the tree.

# %%
# Train a DecisionTreeClassifier() with a maximum depth of 3 and entropy as the criterion for splitting the nodes and evaluate it.
# Show "df_results" (output may vary because of randomness).
# Out:
#                           experiment  accuracy  precision    recall  f1-score  \
# 0         decision_tree_default_args  0.700948   0.456559  0.462069  0.459297
# 1          decision_tree_max_depth_3  0.786730   0.718121  0.368966  0.487472
# 2  decision_tree_max_depth_3_entropy  0.786730   0.718121  0.368966  0.487472
#
#     log_loss
# 0  10.778931
# 1   7.687035
# 2   7.687035

# %%
# Use the sklearn.tree.plot_tree function to display the tree.

# %%
# Train a DecisionTreeClassifier() with a maximum depth of 4 and minimum samples per leaf equal to 1 and evaluate it.
# Show "df_results" (output may vary because of randomness).
# Out:
#                                       experiment  accuracy  precision  \
# 0                     decision_tree_default_args  0.700948   0.456559
# 1                      decision_tree_max_depth_3  0.786730   0.718121
# 2              decision_tree_max_depth_3_entropy  0.786730   0.718121
# 3  decision_tree_max_depth_4_min_samples_leaft_1  0.777725   0.624719
#
#      recall  f1-score   log_loss
# 0  0.462069  0.459297  10.778931
# 1  0.368966  0.487472   7.687035
# 2  0.368966  0.487472   7.687035
# 3  0.479310  0.542439   8.011599

# %%
# Use the ".feature_importances_" property of the model and the columns in the training data to create a table of the feature importances.
# Sort it in a descending order and display it.
# Out:
#                                      column  importance
# 33                  Contract_Month-to-month    0.541050
# 0                                    tenure    0.176474
# 13              InternetService_Fiber optic    0.147367
# 14                       InternetService_No    0.037694
# 1                            MonthlyCharges    0.022270
# 38           PaymentMethod_Electronic check    0.021505
# 2                              TotalCharges    0.021113
# 7                           PhoneService_No    0.013917
# 34                        Contract_One year    0.009662
# 35                        Contract_Two year    0.005711
# 15                        OnlineSecurity_No    0.003238
# 29                          StreamingTV_Yes    0.000000
# 25          TechSupport_No internet service    0.000000
# 26                          TechSupport_Yes    0.000000
# 27                           StreamingTV_No    0.000000
# 28          StreamingTV_No internet service    0.000000
# 31      StreamingMovies_No internet service    0.000000
# 30                       StreamingMovies_No    0.000000
# 23                     DeviceProtection_Yes    0.000000
# 32                      StreamingMovies_Yes    0.000000
# 36  PaymentMethod_Bank transfer (automatic)    0.000000
# 37    PaymentMethod_Credit card (automatic)    0.000000
# 24                           TechSupport_No    0.000000
# 20                         OnlineBackup_Yes    0.000000
# 22     DeviceProtection_No internet service    0.000000
# 21                      DeviceProtection_No    0.000000
# 19         OnlineBackup_No internet service    0.000000
# 18                          OnlineBackup_No    0.000000
# 17                       OnlineSecurity_Yes    0.000000
# 16       OnlineSecurity_No internet service    0.000000
# 12                      InternetService_DSL    0.000000
# 11                        MultipleLines_Yes    0.000000
# 10           MultipleLines_No phone service    0.000000
# 9                          MultipleLines_No    0.000000
# 8                       PaperlessBilling_No    0.000000
# 6                             Dependents_No    0.000000
# 5                                Partner_No    0.000000
# 4                           SeniorCitizen_0    0.000000
# 3                             gender_Female    0.000000
# 39               PaymentMethod_Mailed check    0.000000

# %%
# Visualize the top 10 most important features.
# Out:
# <Axes: title={'center': 'Ten most important features'}, xlabel='importance', ylabel='column'>

# %%
# Display the tree.

# %%
# Display the confusion matrix. What you do see?

# %%
# Train a DecisionTreeClassifier() with a maximum depth of 7 and minimum samples per leaf equal to 3 and evaluate it.
# Show "df_results" (output may vary because of randomness).
# Out:
#                                       experiment  accuracy  precision  \
# 0                     decision_tree_default_args  0.700948   0.456559
# 1                      decision_tree_max_depth_3  0.786730   0.718121
# 2              decision_tree_max_depth_3_entropy  0.786730   0.718121
# 3  decision_tree_max_depth_4_min_samples_leaft_1  0.777725   0.624719
# 4  decision_tree_max_depth_7_min_samples_leaft_3  0.783886   0.628099
#
#      recall  f1-score   log_loss
# 0  0.462069  0.459297  10.778931
# 1  0.368966  0.487472   7.687035
# 2  0.368966  0.487472   7.687035
# 3  0.479310  0.542439   8.011599
# 4  0.524138  0.571429   7.789529

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Model building. Random forest

# %%
# Train a RandomForestClassifier() with 100 trees and evaluate it.
# Show "df_results" (output may vary because of randomness).
# Out:
#                                       experiment  accuracy  precision  \
# 0                     decision_tree_default_args  0.700948   0.456559
# 1                      decision_tree_max_depth_3  0.786730   0.718121
# 2              decision_tree_max_depth_3_entropy  0.786730   0.718121
# 3  decision_tree_max_depth_4_min_samples_leaft_1  0.777725   0.624719
# 4  decision_tree_max_depth_7_min_samples_leaft_3  0.783886   0.628099
# 5                 random_forest_n_estimators_100  0.783886   0.628099
#
#      recall  f1-score   log_loss
# 0  0.462069  0.459297  10.778931
# 1  0.368966  0.487472   7.687035
# 2  0.368966  0.487472   7.687035
# 3  0.479310  0.542439   8.011599
# 4  0.524138  0.571429   7.789529
# 5  0.524138  0.571429   7.789529

# %%
# Train a RandomForestClassifier() with 50 trees and evaluate it.
# Show "df_results" (output may vary because of randomness).
# Out:
#                                       experiment  accuracy  precision  \
# 0                     decision_tree_default_args  0.700948   0.456559
# 1                      decision_tree_max_depth_3  0.786730   0.718121
# 2              decision_tree_max_depth_3_entropy  0.786730   0.718121
# 3  decision_tree_max_depth_4_min_samples_leaft_1  0.777725   0.624719
# 4  decision_tree_max_depth_7_min_samples_leaft_3  0.783886   0.628099
# 5                 random_forest_n_estimators_100  0.783886   0.628099
# 6                  random_forest_n_estimators_50  0.783886   0.649758
#
#      recall  f1-score   log_loss
# 0  0.462069  0.459297  10.778931
# 1  0.368966  0.487472   7.687035
# 2  0.368966  0.487472   7.687035
# 3  0.479310  0.542439   8.011599
# 4  0.524138  0.571429   7.789529
# 5  0.524138  0.571429   7.789529
# 6  0.463793  0.541247   7.789529

# %%
# Train a RandomForestClassifier() with 150 trees and evaluate it.
# Show "df_results" (output may vary because of randomness).
# Out:
#                                       experiment  accuracy  precision  \
# 0                     decision_tree_default_args  0.700948   0.456559
# 1                      decision_tree_max_depth_3  0.786730   0.718121
# 2              decision_tree_max_depth_3_entropy  0.786730   0.718121
# 3  decision_tree_max_depth_4_min_samples_leaft_1  0.777725   0.624719
# 4  decision_tree_max_depth_7_min_samples_leaft_3  0.783886   0.628099
# 5                 random_forest_n_estimators_100  0.783886   0.628099
# 6                  random_forest_n_estimators_50  0.783886   0.649758
# 7                 random_forest_n_estimators_150  0.782464   0.647202
#
#      recall  f1-score   log_loss
# 0  0.462069  0.459297  10.778931
# 1  0.368966  0.487472   7.687035
# 2  0.368966  0.487472   7.687035
# 3  0.479310  0.542439   8.011599
# 4  0.524138  0.571429   7.789529
# 5  0.524138  0.571429   7.789529
# 6  0.463793  0.541247   7.789529
# 7  0.458621  0.536831   7.840776

# %% [markdown]
# ### Hyperparameter tuning via Grid Search

# %%
# Doing this by hand it not efficient and is time consuming.
# Do a grid search for the RandomForestClassifier() on the following values:

# - criterions goes through 'gini', 'entropy'
# - n_estimators goes through 10, 50, 100, 150, 200
# - max_features goes through 1, 'sqrt', 'log2'
# - max_depths goes through None, 2, 3, 4, 5, 10, 20

# Display the best scores.
# Out:
# f1 for (10, 1, None, 'gini'): 0.48
# f1 for (10, 1, None, 'entropy'): 0.50
# f1 for (10, 1, 2, 'gini'): 0.00
# f1 for (10, 1, 2, 'entropy'): 0.00
# f1 for (10, 1, 3, 'gini'): 0.05
# f1 for (10, 1, 3, 'entropy'): 0.00
# f1 for (10, 1, 4, 'gini'): 0.15
# f1 for (10, 1, 4, 'entropy'): 0.00
# f1 for (10, 1, 5, 'gini'): 0.26
# f1 for (10, 1, 5, 'entropy'): 0.30
# f1 for (10, 1, 10, 'gini'): 0.55
# f1 for (10, 1, 10, 'entropy'): 0.57
# f1 for (10, 1, 20, 'gini'): 0.50
# f1 for (10, 1, 20, 'entropy'): 0.49
# f1 for (10, 'sqrt', None, 'gini'): 0.50
# f1 for (10, 'sqrt', None, 'entropy'): 0.51
# f1 for (10, 'sqrt', 2, 'gini'): 0.06
# f1 for (10, 'sqrt', 2, 'entropy'): 0.32
# f1 for (10, 'sqrt', 3, 'gini'): 0.43
# f1 for (10, 'sqrt', 3, 'entropy'): 0.52
# f1 for (10, 'sqrt', 4, 'gini'): 0.51
# f1 for (10, 'sqrt', 4, 'entropy'): 0.55
# f1 for (10, 'sqrt', 5, 'gini'): 0.54
# f1 for (10, 'sqrt', 5, 'entropy'): 0.50
# f1 for (10, 'sqrt', 10, 'gini'): 0.56
# f1 for (10, 'sqrt', 10, 'entropy'): 0.58
# f1 for (10, 'sqrt', 20, 'gini'): 0.53
# f1 for (10, 'sqrt', 20, 'entropy'): 0.53
# f1 for (10, 'log2', None, 'gini'): 0.51
# f1 for (10, 'log2', None, 'entropy'): 0.51
# f1 for (10, 'log2', 2, 'gini'): 0.00
# f1 for (10, 'log2', 2, 'entropy'): 0.37
# f1 for (10, 'log2', 3, 'gini'): 0.40
# f1 for (10, 'log2', 3, 'entropy'): 0.37
# f1 for (10, 'log2', 4, 'gini'): 0.48
# f1 for (10, 'log2', 4, 'entropy'): 0.50
# f1 for (10, 'log2', 5, 'gini'): 0.49
# f1 for (10, 'log2', 5, 'entropy'): 0.56
# f1 for (10, 'log2', 10, 'gini'): 0.56
# f1 for (10, 'log2', 10, 'entropy'): 0.56
# f1 for (10, 'log2', 20, 'gini'): 0.51
# f1 for (10, 'log2', 20, 'entropy'): 0.53
# f1 for (50, 1, None, 'gini'): 0.54
# f1 for (50, 1, None, 'entropy'): 0.53
# f1 for (50, 1, 2, 'gini'): 0.00
# f1 for (50, 1, 2, 'entropy'): 0.00
# f1 for (50, 1, 3, 'gini'): 0.00
# f1 for (50, 1, 3, 'entropy'): 0.00
# f1 for (50, 1, 4, 'gini'): 0.02
# f1 for (50, 1, 4, 'entropy'): 0.04
# f1 for (50, 1, 5, 'gini'): 0.23
# f1 for (50, 1, 5, 'entropy'): 0.25
# f1 for (50, 1, 10, 'gini'): 0.53
# f1 for (50, 1, 10, 'entropy'): 0.54
# f1 for (50, 1, 20, 'gini'): 0.53
# f1 for (50, 1, 20, 'entropy'): 0.53
# f1 for (50, 'sqrt', None, 'gini'): 0.54
# f1 for (50, 'sqrt', None, 'entropy'): 0.54
# f1 for (50, 'sqrt', 2, 'gini'): 0.28
# f1 for (50, 'sqrt', 2, 'entropy'): 0.17
# f1 for (50, 'sqrt', 3, 'gini'): 0.45
# f1 for (50, 'sqrt', 3, 'entropy'): 0.38
# f1 for (50, 'sqrt', 4, 'gini'): 0.49
# f1 for (50, 'sqrt', 4, 'entropy'): 0.48
# f1 for (50, 'sqrt', 5, 'gini'): 0.52
# f1 for (50, 'sqrt', 5, 'entropy'): 0.50
# f1 for (50, 'sqrt', 10, 'gini'): 0.58
# f1 for (50, 'sqrt', 10, 'entropy'): 0.56
# f1 for (50, 'sqrt', 20, 'gini'): 0.54
# f1 for (50, 'sqrt', 20, 'entropy'): 0.56
# f1 for (50, 'log2', None, 'gini'): 0.53
# f1 for (50, 'log2', None, 'entropy'): 0.53
# f1 for (50, 'log2', 2, 'gini'): 0.00
# f1 for (50, 'log2', 2, 'entropy'): 0.00
# f1 for (50, 'log2', 3, 'gini'): 0.42
# f1 for (50, 'log2', 3, 'entropy'): 0.40
# f1 for (50, 'log2', 4, 'gini'): 0.47
# f1 for (50, 'log2', 4, 'entropy'): 0.49
# f1 for (50, 'log2', 5, 'gini'): 0.51
# f1 for (50, 'log2', 5, 'entropy'): 0.52
# f1 for (50, 'log2', 10, 'gini'): 0.56
# f1 for (50, 'log2', 10, 'entropy'): 0.57
# f1 for (50, 'log2', 20, 'gini'): 0.54
# f1 for (50, 'log2', 20, 'entropy'): 0.55
# f1 for (100, 1, None, 'gini'): 0.53
# f1 for (100, 1, None, 'entropy'): 0.54
# f1 for (100, 1, 2, 'gini'): 0.00
# f1 for (100, 1, 2, 'entropy'): 0.00
# f1 for (100, 1, 3, 'gini'): 0.00
# f1 for (100, 1, 3, 'entropy'): 0.00
# f1 for (100, 1, 4, 'gini'): 0.12
# f1 for (100, 1, 4, 'entropy'): 0.05
# f1 for (100, 1, 5, 'gini'): 0.26
# f1 for (100, 1, 5, 'entropy'): 0.22
# f1 for (100, 1, 10, 'gini'): 0.54
# f1 for (100, 1, 10, 'entropy'): 0.54
# f1 for (100, 1, 20, 'gini'): 0.53
# f1 for (100, 1, 20, 'entropy'): 0.54
# f1 for (100, 'sqrt', None, 'gini'): 0.55
# f1 for (100, 'sqrt', None, 'entropy'): 0.55
# f1 for (100, 'sqrt', 2, 'gini'): 0.11
# f1 for (100, 'sqrt', 2, 'entropy'): 0.00
# f1 for (100, 'sqrt', 3, 'gini'): 0.44
# f1 for (100, 'sqrt', 3, 'entropy'): 0.40
# f1 for (100, 'sqrt', 4, 'gini'): 0.50
# f1 for (100, 'sqrt', 4, 'entropy'): 0.50
# f1 for (100, 'sqrt', 5, 'gini'): 0.52
# f1 for (100, 'sqrt', 5, 'entropy'): 0.52
# f1 for (100, 'sqrt', 10, 'gini'): 0.58
# f1 for (100, 'sqrt', 10, 'entropy'): 0.58
# f1 for (100, 'sqrt', 20, 'gini'): 0.56
# f1 for (100, 'sqrt', 20, 'entropy'): 0.54
# f1 for (100, 'log2', None, 'gini'): 0.52
# f1 for (100, 'log2', None, 'entropy'): 0.54
# f1 for (100, 'log2', 2, 'gini'): 0.00
# f1 for (100, 'log2', 2, 'entropy'): 0.00
# f1 for (100, 'log2', 3, 'gini'): 0.38
# f1 for (100, 'log2', 3, 'entropy'): 0.39
# f1 for (100, 'log2', 4, 'gini'): 0.47
# f1 for (100, 'log2', 4, 'entropy'): 0.45
# f1 for (100, 'log2', 5, 'gini'): 0.50
# f1 for (100, 'log2', 5, 'entropy'): 0.51
# f1 for (100, 'log2', 10, 'gini'): 0.57
# f1 for (100, 'log2', 10, 'entropy'): 0.58
# f1 for (100, 'log2', 20, 'gini'): 0.53
# f1 for (100, 'log2', 20, 'entropy'): 0.55
# f1 for (150, 1, None, 'gini'): 0.53
# f1 for (150, 1, None, 'entropy'): 0.54
# f1 for (150, 1, 2, 'gini'): 0.00
# f1 for (150, 1, 2, 'entropy'): 0.00
# f1 for (150, 1, 3, 'gini'): 0.00
# f1 for (150, 1, 3, 'entropy'): 0.00
# f1 for (150, 1, 4, 'gini'): 0.12
# f1 for (150, 1, 4, 'entropy'): 0.02
# f1 for (150, 1, 5, 'gini'): 0.20
# f1 for (150, 1, 5, 'entropy'): 0.19
# f1 for (150, 1, 10, 'gini'): 0.54
# f1 for (150, 1, 10, 'entropy'): 0.54
# f1 for (150, 1, 20, 'gini'): 0.53
# f1 for (150, 1, 20, 'entropy'): 0.53
# f1 for (150, 'sqrt', None, 'gini'): 0.54
# f1 for (150, 'sqrt', None, 'entropy'): 0.54
# f1 for (150, 'sqrt', 2, 'gini'): 0.24
# f1 for (150, 'sqrt', 2, 'entropy'): 0.00
# f1 for (150, 'sqrt', 3, 'gini'): 0.43
# f1 for (150, 'sqrt', 3, 'entropy'): 0.39
# f1 for (150, 'sqrt', 4, 'gini'): 0.49
# f1 for (150, 'sqrt', 4, 'entropy'): 0.49
# f1 for (150, 'sqrt', 5, 'gini'): 0.53
# f1 for (150, 'sqrt', 5, 'entropy'): 0.53
# f1 for (150, 'sqrt', 10, 'gini'): 0.57
# f1 for (150, 'sqrt', 10, 'entropy'): 0.57
# f1 for (150, 'sqrt', 20, 'gini'): 0.54
# f1 for (150, 'sqrt', 20, 'entropy'): 0.55
# f1 for (150, 'log2', None, 'gini'): 0.55
# f1 for (150, 'log2', None, 'entropy'): 0.55
# f1 for (150, 'log2', 2, 'gini'): 0.17
# f1 for (150, 'log2', 2, 'entropy'): 0.00
# f1 for (150, 'log2', 3, 'gini'): 0.38
# f1 for (150, 'log2', 3, 'entropy'): 0.38
# f1 for (150, 'log2', 4, 'gini'): 0.48
# f1 for (150, 'log2', 4, 'entropy'): 0.47
# f1 for (150, 'log2', 5, 'gini'): 0.51
# f1 for (150, 'log2', 5, 'entropy'): 0.50
# f1 for (150, 'log2', 10, 'gini'): 0.56
# f1 for (150, 'log2', 10, 'entropy'): 0.57
# f1 for (150, 'log2', 20, 'gini'): 0.55
# f1 for (150, 'log2', 20, 'entropy'): 0.55
# f1 for (200, 1, None, 'gini'): 0.54
# f1 for (200, 1, None, 'entropy'): 0.53
# f1 for (200, 1, 2, 'gini'): 0.00
# f1 for (200, 1, 2, 'entropy'): 0.00
# f1 for (200, 1, 3, 'gini'): 0.00
# f1 for (200, 1, 3, 'entropy'): 0.00
# f1 for (200, 1, 4, 'gini'): 0.06
# f1 for (200, 1, 4, 'entropy'): 0.04
# f1 for (200, 1, 5, 'gini'): 0.25
# f1 for (200, 1, 5, 'entropy'): 0.26
# f1 for (200, 1, 10, 'gini'): 0.54
# f1 for (200, 1, 10, 'entropy'): 0.55
# f1 for (200, 1, 20, 'gini'): 0.53
# f1 for (200, 1, 20, 'entropy'): 0.53
# f1 for (200, 'sqrt', None, 'gini'): 0.54
# f1 for (200, 'sqrt', None, 'entropy'): 0.54
# f1 for (200, 'sqrt', 2, 'gini'): 0.18
# f1 for (200, 'sqrt', 2, 'entropy'): 0.00
# f1 for (200, 'sqrt', 3, 'gini'): 0.41
# f1 for (200, 'sqrt', 3, 'entropy'): 0.40
# f1 for (200, 'sqrt', 4, 'gini'): 0.50
# f1 for (200, 'sqrt', 4, 'entropy'): 0.50
# f1 for (200, 'sqrt', 5, 'gini'): 0.52
# f1 for (200, 'sqrt', 5, 'entropy'): 0.52
# f1 for (200, 'sqrt', 10, 'gini'): 0.58
# f1 for (200, 'sqrt', 10, 'entropy'): 0.56
# f1 for (200, 'sqrt', 20, 'gini'): 0.53
# f1 for (200, 'sqrt', 20, 'entropy'): 0.54
# f1 for (200, 'log2', None, 'gini'): 0.54
# f1 for (200, 'log2', None, 'entropy'): 0.55
# f1 for (200, 'log2', 2, 'gini'): 0.15
# f1 for (200, 'log2', 2, 'entropy'): 0.00
# f1 for (200, 'log2', 3, 'gini'): 0.37
# f1 for (200, 'log2', 3, 'entropy'): 0.34
# f1 for (200, 'log2', 4, 'gini'): 0.45
# f1 for (200, 'log2', 4, 'entropy'): 0.48
# f1 for (200, 'log2', 5, 'gini'): 0.51
# f1 for (200, 'log2', 5, 'entropy'): 0.51
# f1 for (200, 'log2', 10, 'gini'): 0.58
# f1 for (200, 'log2', 10, 'entropy'): 0.56
# f1 for (200, 'log2', 20, 'gini'): 0.54
# f1 for (200, 'log2', 20, 'entropy'): 0.55
# [((200, 'log2', 10, 'gini'), 0.5780933062880325),
#  ((100, 'sqrt', 10, 'entropy'), 0.5771543086172345),
#  ((50, 'sqrt', 10, 'gini'), 0.5763052208835341),
#  ((100, 'log2', 10, 'entropy'), 0.5763052208835341),
#  ((200, 'sqrt', 10, 'gini'), 0.576),
#  ((100, 'sqrt', 10, 'gini'), 0.5757575757575758),
#  ((10, 'sqrt', 10, 'entropy'), 0.575098814229249),
#  ((150, 'sqrt', 10, 'entropy'), 0.5711382113821138),
#  ((50, 'log2', 10, 'entropy'), 0.570281124497992),
#  ((100, 'log2', 10, 'gini'), 0.5688259109311741),
#  ((150, 'sqrt', 10, 'gini'), 0.5685279187817259),
#  ((10, 1, 10, 'entropy'), 0.5658835546475995),
#  ((150, 'log2', 10, 'entropy'), 0.5650406504065041),
#  ((10, 'log2', 10, 'entropy'), 0.5647058823529412),
#  ((10, 'log2', 10, 'gini'), 0.5636363636363636),
#  ((150, 'log2', 10, 'gini'), 0.5636363636363636),
#  ((200, 'log2', 10, 'entropy'), 0.5621840242669363),
#  ((10, 'sqrt', 10, 'gini'), 0.5621301775147929),
#  ((50, 'log2', 10, 'gini'), 0.5607287449392713),
#  ((200, 'sqrt', 10, 'entropy'), 0.560081466395112),
#  ((50, 'sqrt', 10, 'entropy'), 0.5597609561752988),
#  ((50, 'sqrt', 20, 'entropy'), 0.5580933465739821),
#  ((100, 'sqrt', 20, 'gini'), 0.5566600397614314),
#  ((10, 'log2', 5, 'entropy'), 0.5564681724845996),
#  ((100, 'sqrt', None, 'gini'), 0.5535353535353535),
#  ((10, 1, 10, 'gini'), 0.5534079348931842),
#  ((10, 'sqrt', 4, 'entropy'), 0.5532359081419624),
#  ((150, 'sqrt', 20, 'entropy'), 0.5511022044088176),
#  ((50, 'log2', 20, 'entropy'), 0.5506958250497018),
#  ((150, 'log2', 20, 'entropy'), 0.5504950495049505),
#  ((150, 'log2', None, 'entropy'), 0.550253807106599),
#  ((100, 'log2', 20, 'entropy'), 0.5487437185929648),
#  ((200, 'log2', 20, 'entropy'), 0.5483870967741935),
#  ((200, 'log2', None, 'entropy'), 0.5483549351944168),
#  ((100, 'sqrt', None, 'entropy'), 0.5481927710843374),
#  ((150, 'log2', 20, 'gini'), 0.5474525474525475),
#  ((150, 'log2', None, 'gini'), 0.5462012320328542),
#  ((200, 1, 10, 'entropy'), 0.5454545454545454),
#  ((50, 'sqrt', None, 'gini'), 0.5441767068273092),
#  ((200, 'sqrt', 20, 'entropy'), 0.544),
#  ((150, 'sqrt', None, 'gini'), 0.5432595573440644),
#  ((100, 1, 10, 'entropy'), 0.542766631467793),
#  ((200, 'sqrt', None, 'entropy'), 0.542713567839196),
#  ((100, 'sqrt', 20, 'entropy'), 0.5422045680238332),
#  ((100, 1, 10, 'gini'), 0.5419766206163655),
#  ((200, 'log2', 20, 'gini'), 0.5419615773508595),
#  ((50, 1, None, 'gini'), 0.5419222903885481),
#  ((10, 'sqrt', 5, 'gini'), 0.5415778251599147),
#  ((200, 'log2', None, 'gini'), 0.5414141414141415),
#  ((200, 1, None, 'gini'), 0.5412474849094567),
#  ((50, 'sqrt', 20, 'gini'), 0.5410821643286573),
#  ((100, 1, 20, 'entropy'), 0.541033434650456),
#  ((100, 'log2', None, 'entropy'), 0.5403225806451613),
#  ((150, 'sqrt', None, 'entropy'), 0.539714867617108),
#  ((50, 1, 10, 'entropy'), 0.5394456289978679),
#  ((200, 1, 10, 'gini'), 0.5392781316348195),
#  ((50, 'sqrt', None, 'entropy'), 0.5382323733862959),
#  ((150, 1, 10, 'entropy'), 0.5375661375661376),
#  ((50, 'log2', 20, 'gini'), 0.537525354969574),
#  ((150, 'sqrt', 20, 'gini'), 0.5374625374625375),
#  ((150, 1, 10, 'gini'), 0.5373134328358209),
#  ((150, 1, None, 'entropy'), 0.536734693877551),
#  ((200, 'sqrt', None, 'gini'), 0.5366834170854271),
#  ((100, 1, None, 'entropy'), 0.5353846153846153),
#  ((150, 1, 20, 'entropy'), 0.5349544072948328),
#  ((10, 'sqrt', 20, 'entropy'), 0.5345911949685535),
#  ((50, 1, None, 'entropy'), 0.5345528455284553),
#  ((200, 'sqrt', 20, 'gini'), 0.5334665334665335),
#  ((200, 1, 20, 'entropy'), 0.5333333333333333),
#  ((150, 'sqrt', 5, 'entropy'), 0.532051282051282),
#  ((100, 1, 20, 'gini'), 0.5310274669379451),
#  ((200, 1, None, 'entropy'), 0.5310274669379451),
#  ((50, 1, 10, 'gini'), 0.5304812834224599),
#  ((100, 1, None, 'gini'), 0.5300713557594292),
#  ((200, 1, 20, 'gini'), 0.5299492385786801),
#  ((150, 1, 20, 'gini'), 0.5296523517382413),
#  ((100, 'log2', 20, 'gini'), 0.5294117647058824),
#  ((50, 'log2', None, 'entropy'), 0.5292929292929293),
#  ((50, 1, 20, 'entropy'), 0.52834008097166),
#  ((10, 'sqrt', 20, 'gini'), 0.5282631038026722),
#  ((10, 'log2', 20, 'entropy'), 0.5272727272727272),
#  ((50, 1, 20, 'gini'), 0.5269582909460834),
#  ((50, 'log2', None, 'gini'), 0.5269582909460834),
#  ((150, 1, None, 'gini'), 0.5264227642276422),
#  ((150, 'sqrt', 5, 'gini'), 0.5251875669882101),
#  ((100, 'log2', None, 'gini'), 0.5240532241555783),
#  ((10, 'sqrt', 3, 'entropy'), 0.5226019845644984),
#  ((200, 'sqrt', 5, 'entropy'), 0.5225806451612903),
#  ((100, 'sqrt', 5, 'gini'), 0.5198711063372717),
#  ((100, 'sqrt', 5, 'entropy'), 0.51931330472103),
#  ((50, 'log2', 5, 'entropy'), 0.5186813186813187),
#  ((200, 'sqrt', 5, 'gini'), 0.5177228786251342),
#  ((50, 'sqrt', 5, 'gini'), 0.5161987041036717),
#  ((10, 'log2', None, 'gini'), 0.5136268343815513),
#  ((150, 'log2', 5, 'gini'), 0.5131578947368421),
#  ((200, 'log2', 5, 'gini'), 0.5125958378970427),
#  ((10, 'log2', 20, 'gini'), 0.5119170984455959),
#  ((10, 'log2', None, 'entropy'), 0.5110410094637224),
#  ((10, 'sqrt', None, 'entropy'), 0.5100529100529101),
#  ((100, 'log2', 5, 'entropy'), 0.5093715545755237),
#  ((10, 'sqrt', 4, 'gini'), 0.5088888888888888),
#  ((50, 'log2', 5, 'gini'), 0.507103825136612),
#  ((200, 'log2', 5, 'entropy'), 0.5061315496098104),
#  ((200, 'sqrt', 4, 'gini'), 0.504424778761062),
#  ((100, 'sqrt', 4, 'entropy'), 0.5033259423503326),
#  ((200, 'sqrt', 4, 'entropy'), 0.5022321428571429),
#  ((10, 1, 20, 'gini'), 0.5015739769150053),
#  ((100, 'sqrt', 4, 'gini'), 0.5011185682326622),
#  ((50, 'sqrt', 5, 'entropy'), 0.5005512679162073),
#  ((10, 'sqrt', 5, 'entropy'), 0.49943757030371205),
#  ((10, 'log2', 4, 'entropy'), 0.4983314794215795),
#  ((150, 'log2', 5, 'entropy'), 0.496054114994363),
#  ((10, 1, None, 'entropy'), 0.49586776859504134),
#  ((100, 'log2', 5, 'gini'), 0.49557522123893805),
#  ((10, 'sqrt', None, 'gini'), 0.49523809523809526),
#  ((150, 'sqrt', 4, 'gini'), 0.4943820224719101),
#  ((150, 'sqrt', 4, 'entropy'), 0.49138920780711826),
#  ((10, 1, 20, 'entropy'), 0.49129989764585463),
#  ((10, 'log2', 5, 'gini'), 0.48630887185104055),
#  ((50, 'log2', 4, 'entropy'), 0.4861751152073733),
#  ((50, 'sqrt', 4, 'gini'), 0.48600223964165734),
#  ((150, 'log2', 4, 'gini'), 0.48323699421965316),
#  ((10, 1, None, 'gini'), 0.47958115183246075),
#  ((10, 'log2', 4, 'gini'), 0.47685185185185186),
#  ((200, 'log2', 4, 'entropy'), 0.47540983606557374),
#  ((50, 'sqrt', 4, 'entropy'), 0.47520184544405997),
#  ((100, 'log2', 4, 'gini'), 0.4734982332155477),
#  ((150, 'log2', 4, 'entropy'), 0.4700352526439483),
#  ((50, 'log2', 4, 'gini'), 0.4678362573099415),
#  ((100, 'log2', 4, 'entropy'), 0.45161290322580644),
#  ((200, 'log2', 4, 'gini'), 0.4510739856801909),
#  ((50, 'sqrt', 3, 'gini'), 0.44683393070489846),
#  ((100, 'sqrt', 3, 'gini'), 0.43818849449204406),
#  ((150, 'sqrt', 3, 'gini'), 0.43184559710494574),
#  ((10, 'sqrt', 3, 'gini'), 0.4278728606356968),
#  ((50, 'log2', 3, 'gini'), 0.4231242312423124),
#  ((200, 'sqrt', 3, 'gini'), 0.40561224489795916),
#  ((200, 'sqrt', 3, 'entropy'), 0.40304182509505704),
#  ((100, 'sqrt', 3, 'entropy'), 0.4005037783375315),
#  ((50, 'log2', 3, 'entropy'), 0.3969465648854962),
#  ((10, 'log2', 3, 'gini'), 0.3963963963963964),
#  ((150, 'sqrt', 3, 'entropy'), 0.3861003861003861),
#  ((100, 'log2', 3, 'entropy'), 0.3855109961190168),
#  ((150, 'log2', 3, 'gini'), 0.3843137254901961),
#  ((50, 'sqrt', 3, 'entropy'), 0.38033635187580855),
#  ((150, 'log2', 3, 'entropy'), 0.3802083333333333),
#  ((100, 'log2', 3, 'gini'), 0.3767741935483871),
#  ((200, 'log2', 3, 'gini'), 0.37270341207349084),
#  ((10, 'log2', 3, 'entropy'), 0.36821192052980134),
#  ((10, 'log2', 2, 'entropy'), 0.36649214659685864),
#  ((200, 'log2', 3, 'entropy'), 0.34332425068119893),
#  ((10, 'sqrt', 2, 'entropy'), 0.3179347826086957),
#  ((10, 1, 5, 'entropy'), 0.2950354609929078),
#  ((50, 'sqrt', 2, 'gini'), 0.2792022792022792),
#  ((100, 1, 5, 'gini'), 0.2612481857764877),
#  ((200, 1, 5, 'entropy'), 0.2608695652173913),
#  ((10, 1, 5, 'gini'), 0.2575976845151954),
#  ((200, 1, 5, 'gini'), 0.25),
#  ((50, 1, 5, 'entropy'), 0.24705882352941178),
#  ((150, 'sqrt', 2, 'gini'), 0.24188790560471976),
#  ((50, 1, 5, 'gini'), 0.228486646884273),
#  ((100, 1, 5, 'entropy'), 0.2175226586102719),
#  ((150, 1, 5, 'gini'), 0.2039573820395738),
#  ((150, 1, 5, 'entropy'), 0.19207317073170732),
#  ((200, 'sqrt', 2, 'gini'), 0.18098159509202455),
#  ((50, 'sqrt', 2, 'entropy'), 0.1728395061728395),
#  ((150, 'log2', 2, 'gini'), 0.17001545595054096),
#  ((200, 'log2', 2, 'gini'), 0.15070643642072212),
#  ((10, 1, 4, 'gini'), 0.14860681114551083),
#  ((150, 1, 4, 'gini'), 0.12460063897763578),
#  ((100, 1, 4, 'gini'), 0.1216),
#  ((100, 'sqrt', 2, 'gini'), 0.11003236245954692),
#  ((10, 'sqrt', 2, 'gini'), 0.06301824212271974),
#  ((200, 1, 4, 'gini'), 0.06301824212271974),
#  ((100, 1, 4, 'entropy'), 0.05351170568561873),
#  ((10, 1, 3, 'gini'), 0.05016722408026756),
#  ((50, 1, 4, 'entropy'), 0.0436241610738255),
#  ((200, 1, 4, 'entropy'), 0.03709949409780776),
#  ((50, 1, 4, 'gini'), 0.023809523809523808),
#  ((150, 1, 4, 'entropy'), 0.020442930153321975),
#  ((10, 1, 2, 'gini'), 0.0),
#  ((10, 1, 2, 'entropy'), 0.0),
#  ((10, 1, 3, 'entropy'), 0.0),
#  ((10, 1, 4, 'entropy'), 0.0),
#  ((10, 'log2', 2, 'gini'), 0.0),
#  ((50, 1, 2, 'gini'), 0.0),
#  ((50, 1, 2, 'entropy'), 0.0),
#  ((50, 1, 3, 'gini'), 0.0),
#  ((50, 1, 3, 'entropy'), 0.0),
#  ((50, 'log2', 2, 'gini'), 0.0),
#  ((50, 'log2', 2, 'entropy'), 0.0),
#  ((100, 1, 2, 'gini'), 0.0),
#  ((100, 1, 2, 'entropy'), 0.0),
#  ((100, 1, 3, 'gini'), 0.0),
#  ((100, 1, 3, 'entropy'), 0.0),
#  ((100, 'sqrt', 2, 'entropy'), 0.0),
#  ((100, 'log2', 2, 'gini'), 0.0),
#  ((100, 'log2', 2, 'entropy'), 0.0),
#  ((150, 1, 2, 'gini'), 0.0),
#  ((150, 1, 2, 'entropy'), 0.0),
#  ((150, 1, 3, 'gini'), 0.0),
#  ((150, 1, 3, 'entropy'), 0.0),
#  ((150, 'sqrt', 2, 'entropy'), 0.0),
#  ((150, 'log2', 2, 'entropy'), 0.0),
#  ((200, 1, 2, 'gini'), 0.0),
#  ((200, 1, 2, 'entropy'), 0.0),
#  ((200, 1, 3, 'gini'), 0.0),
#  ((200, 1, 3, 'entropy'), 0.0),
#  ((200, 'sqrt', 2, 'entropy'), 0.0),
#  ((200, 'log2', 2, 'entropy'), 0.0)]

# %%
# Print the best scores.
# What are the best parameters?
# Out:
# [((200, 'log2', 10, 'gini'), 0.5780933062880325),
#  ((100, 'sqrt', 10, 'entropy'), 0.5771543086172345),
#  ((50, 'sqrt', 10, 'gini'), 0.5763052208835341),
#  ((100, 'log2', 10, 'entropy'), 0.5763052208835341),
#  ((200, 'sqrt', 10, 'gini'), 0.576),
#  ((100, 'sqrt', 10, 'gini'), 0.5757575757575758),
#  ((10, 'sqrt', 10, 'entropy'), 0.575098814229249),
#  ((150, 'sqrt', 10, 'entropy'), 0.5711382113821138),
#  ((50, 'log2', 10, 'entropy'), 0.570281124497992),
#  ((100, 'log2', 10, 'gini'), 0.5688259109311741),
#  ((150, 'sqrt', 10, 'gini'), 0.5685279187817259),
#  ((10, 1, 10, 'entropy'), 0.5658835546475995),
#  ((150, 'log2', 10, 'entropy'), 0.5650406504065041),
#  ((10, 'log2', 10, 'entropy'), 0.5647058823529412),
#  ((10, 'log2', 10, 'gini'), 0.5636363636363636),
#  ((150, 'log2', 10, 'gini'), 0.5636363636363636),
#  ((200, 'log2', 10, 'entropy'), 0.5621840242669363),
#  ((10, 'sqrt', 10, 'gini'), 0.5621301775147929),
#  ((50, 'log2', 10, 'gini'), 0.5607287449392713),
#  ((200, 'sqrt', 10, 'entropy'), 0.560081466395112),
#  ((50, 'sqrt', 10, 'entropy'), 0.5597609561752988),
#  ((50, 'sqrt', 20, 'entropy'), 0.5580933465739821),
#  ((100, 'sqrt', 20, 'gini'), 0.5566600397614314),
#  ((10, 'log2', 5, 'entropy'), 0.5564681724845996),
#  ((100, 'sqrt', None, 'gini'), 0.5535353535353535),
#  ((10, 1, 10, 'gini'), 0.5534079348931842),
#  ((10, 'sqrt', 4, 'entropy'), 0.5532359081419624),
#  ((150, 'sqrt', 20, 'entropy'), 0.5511022044088176),
#  ((50, 'log2', 20, 'entropy'), 0.5506958250497018),
#  ((150, 'log2', 20, 'entropy'), 0.5504950495049505),
#  ((150, 'log2', None, 'entropy'), 0.550253807106599),
#  ((100, 'log2', 20, 'entropy'), 0.5487437185929648),
#  ((200, 'log2', 20, 'entropy'), 0.5483870967741935),
#  ((200, 'log2', None, 'entropy'), 0.5483549351944168),
#  ((100, 'sqrt', None, 'entropy'), 0.5481927710843374),
#  ((150, 'log2', 20, 'gini'), 0.5474525474525475),
#  ((150, 'log2', None, 'gini'), 0.5462012320328542),
#  ((200, 1, 10, 'entropy'), 0.5454545454545454),
#  ((50, 'sqrt', None, 'gini'), 0.5441767068273092),
#  ((200, 'sqrt', 20, 'entropy'), 0.544),
#  ((150, 'sqrt', None, 'gini'), 0.5432595573440644),
#  ((100, 1, 10, 'entropy'), 0.542766631467793),
#  ((200, 'sqrt', None, 'entropy'), 0.542713567839196),
#  ((100, 'sqrt', 20, 'entropy'), 0.5422045680238332),
#  ((100, 1, 10, 'gini'), 0.5419766206163655),
#  ((200, 'log2', 20, 'gini'), 0.5419615773508595),
#  ((50, 1, None, 'gini'), 0.5419222903885481),
#  ((10, 'sqrt', 5, 'gini'), 0.5415778251599147),
#  ((200, 'log2', None, 'gini'), 0.5414141414141415),
#  ((200, 1, None, 'gini'), 0.5412474849094567),
#  ((50, 'sqrt', 20, 'gini'), 0.5410821643286573),
#  ((100, 1, 20, 'entropy'), 0.541033434650456),
#  ((100, 'log2', None, 'entropy'), 0.5403225806451613),
#  ((150, 'sqrt', None, 'entropy'), 0.539714867617108),
#  ((50, 1, 10, 'entropy'), 0.5394456289978679),
#  ((200, 1, 10, 'gini'), 0.5392781316348195),
#  ((50, 'sqrt', None, 'entropy'), 0.5382323733862959),
#  ((150, 1, 10, 'entropy'), 0.5375661375661376),
#  ((50, 'log2', 20, 'gini'), 0.537525354969574),
#  ((150, 'sqrt', 20, 'gini'), 0.5374625374625375),
#  ((150, 1, 10, 'gini'), 0.5373134328358209),
#  ((150, 1, None, 'entropy'), 0.536734693877551),
#  ((200, 'sqrt', None, 'gini'), 0.5366834170854271),
#  ((100, 1, None, 'entropy'), 0.5353846153846153),
#  ((150, 1, 20, 'entropy'), 0.5349544072948328),
#  ((10, 'sqrt', 20, 'entropy'), 0.5345911949685535),
#  ((50, 1, None, 'entropy'), 0.5345528455284553),
#  ((200, 'sqrt', 20, 'gini'), 0.5334665334665335),
#  ((200, 1, 20, 'entropy'), 0.5333333333333333),
#  ((150, 'sqrt', 5, 'entropy'), 0.532051282051282),
#  ((100, 1, 20, 'gini'), 0.5310274669379451),
#  ((200, 1, None, 'entropy'), 0.5310274669379451),
#  ((50, 1, 10, 'gini'), 0.5304812834224599),
#  ((100, 1, None, 'gini'), 0.5300713557594292),
#  ((200, 1, 20, 'gini'), 0.5299492385786801),
#  ((150, 1, 20, 'gini'), 0.5296523517382413),
#  ((100, 'log2', 20, 'gini'), 0.5294117647058824),
#  ((50, 'log2', None, 'entropy'), 0.5292929292929293),
#  ((50, 1, 20, 'entropy'), 0.52834008097166),
#  ((10, 'sqrt', 20, 'gini'), 0.5282631038026722),
#  ((10, 'log2', 20, 'entropy'), 0.5272727272727272),
#  ((50, 1, 20, 'gini'), 0.5269582909460834),
#  ((50, 'log2', None, 'gini'), 0.5269582909460834),
#  ((150, 1, None, 'gini'), 0.5264227642276422),
#  ((150, 'sqrt', 5, 'gini'), 0.5251875669882101),
#  ((100, 'log2', None, 'gini'), 0.5240532241555783),
#  ((10, 'sqrt', 3, 'entropy'), 0.5226019845644984),
#  ((200, 'sqrt', 5, 'entropy'), 0.5225806451612903),
#  ((100, 'sqrt', 5, 'gini'), 0.5198711063372717),
#  ((100, 'sqrt', 5, 'entropy'), 0.51931330472103),
#  ((50, 'log2', 5, 'entropy'), 0.5186813186813187),
#  ((200, 'sqrt', 5, 'gini'), 0.5177228786251342),
#  ((50, 'sqrt', 5, 'gini'), 0.5161987041036717),
#  ((10, 'log2', None, 'gini'), 0.5136268343815513),
#  ((150, 'log2', 5, 'gini'), 0.5131578947368421),
#  ((200, 'log2', 5, 'gini'), 0.5125958378970427),
#  ((10, 'log2', 20, 'gini'), 0.5119170984455959),
#  ((10, 'log2', None, 'entropy'), 0.5110410094637224),
#  ((10, 'sqrt', None, 'entropy'), 0.5100529100529101),
#  ((100, 'log2', 5, 'entropy'), 0.5093715545755237),
#  ((10, 'sqrt', 4, 'gini'), 0.5088888888888888),
#  ((50, 'log2', 5, 'gini'), 0.507103825136612),
#  ((200, 'log2', 5, 'entropy'), 0.5061315496098104),
#  ((200, 'sqrt', 4, 'gini'), 0.504424778761062),
#  ((100, 'sqrt', 4, 'entropy'), 0.5033259423503326),
#  ((200, 'sqrt', 4, 'entropy'), 0.5022321428571429),
#  ((10, 1, 20, 'gini'), 0.5015739769150053),
#  ((100, 'sqrt', 4, 'gini'), 0.5011185682326622),
#  ((50, 'sqrt', 5, 'entropy'), 0.5005512679162073),
#  ((10, 'sqrt', 5, 'entropy'), 0.49943757030371205),
#  ((10, 'log2', 4, 'entropy'), 0.4983314794215795),
#  ((150, 'log2', 5, 'entropy'), 0.496054114994363),
#  ((10, 1, None, 'entropy'), 0.49586776859504134),
#  ((100, 'log2', 5, 'gini'), 0.49557522123893805),
#  ((10, 'sqrt', None, 'gini'), 0.49523809523809526),
#  ((150, 'sqrt', 4, 'gini'), 0.4943820224719101),
#  ((150, 'sqrt', 4, 'entropy'), 0.49138920780711826),
#  ((10, 1, 20, 'entropy'), 0.49129989764585463),
#  ((10, 'log2', 5, 'gini'), 0.48630887185104055),
#  ((50, 'log2', 4, 'entropy'), 0.4861751152073733),
#  ((50, 'sqrt', 4, 'gini'), 0.48600223964165734),
#  ((150, 'log2', 4, 'gini'), 0.48323699421965316),
#  ((10, 1, None, 'gini'), 0.47958115183246075),
#  ((10, 'log2', 4, 'gini'), 0.47685185185185186),
#  ((200, 'log2', 4, 'entropy'), 0.47540983606557374),
#  ((50, 'sqrt', 4, 'entropy'), 0.47520184544405997),
#  ((100, 'log2', 4, 'gini'), 0.4734982332155477),
#  ((150, 'log2', 4, 'entropy'), 0.4700352526439483),
#  ((50, 'log2', 4, 'gini'), 0.4678362573099415),
#  ((100, 'log2', 4, 'entropy'), 0.45161290322580644),
#  ((200, 'log2', 4, 'gini'), 0.4510739856801909),
#  ((50, 'sqrt', 3, 'gini'), 0.44683393070489846),
#  ((100, 'sqrt', 3, 'gini'), 0.43818849449204406),
#  ((150, 'sqrt', 3, 'gini'), 0.43184559710494574),
#  ((10, 'sqrt', 3, 'gini'), 0.4278728606356968),
#  ((50, 'log2', 3, 'gini'), 0.4231242312423124),
#  ((200, 'sqrt', 3, 'gini'), 0.40561224489795916),
#  ((200, 'sqrt', 3, 'entropy'), 0.40304182509505704),
#  ((100, 'sqrt', 3, 'entropy'), 0.4005037783375315),
#  ((50, 'log2', 3, 'entropy'), 0.3969465648854962),
#  ((10, 'log2', 3, 'gini'), 0.3963963963963964),
#  ((150, 'sqrt', 3, 'entropy'), 0.3861003861003861),
#  ((100, 'log2', 3, 'entropy'), 0.3855109961190168),
#  ((150, 'log2', 3, 'gini'), 0.3843137254901961),
#  ((50, 'sqrt', 3, 'entropy'), 0.38033635187580855),
#  ((150, 'log2', 3, 'entropy'), 0.3802083333333333),
#  ((100, 'log2', 3, 'gini'), 0.3767741935483871),
#  ((200, 'log2', 3, 'gini'), 0.37270341207349084),
#  ((10, 'log2', 3, 'entropy'), 0.36821192052980134),
#  ((10, 'log2', 2, 'entropy'), 0.36649214659685864),
#  ((200, 'log2', 3, 'entropy'), 0.34332425068119893),
#  ((10, 'sqrt', 2, 'entropy'), 0.3179347826086957),
#  ((10, 1, 5, 'entropy'), 0.2950354609929078),
#  ((50, 'sqrt', 2, 'gini'), 0.2792022792022792),
#  ((100, 1, 5, 'gini'), 0.2612481857764877),
#  ((200, 1, 5, 'entropy'), 0.2608695652173913),
#  ((10, 1, 5, 'gini'), 0.2575976845151954),
#  ((200, 1, 5, 'gini'), 0.25),
#  ((50, 1, 5, 'entropy'), 0.24705882352941178),
#  ((150, 'sqrt', 2, 'gini'), 0.24188790560471976),
#  ((50, 1, 5, 'gini'), 0.228486646884273),
#  ((100, 1, 5, 'entropy'), 0.2175226586102719),
#  ((150, 1, 5, 'gini'), 0.2039573820395738),
#  ((150, 1, 5, 'entropy'), 0.19207317073170732),
#  ((200, 'sqrt', 2, 'gini'), 0.18098159509202455),
#  ((50, 'sqrt', 2, 'entropy'), 0.1728395061728395),
#  ((150, 'log2', 2, 'gini'), 0.17001545595054096),
#  ((200, 'log2', 2, 'gini'), 0.15070643642072212),
#  ((10, 1, 4, 'gini'), 0.14860681114551083),
#  ((150, 1, 4, 'gini'), 0.12460063897763578),
#  ((100, 1, 4, 'gini'), 0.1216),
#  ((100, 'sqrt', 2, 'gini'), 0.11003236245954692),
#  ((10, 'sqrt', 2, 'gini'), 0.06301824212271974),
#  ((200, 1, 4, 'gini'), 0.06301824212271974),
#  ((100, 1, 4, 'entropy'), 0.05351170568561873),
#  ((10, 1, 3, 'gini'), 0.05016722408026756),
#  ((50, 1, 4, 'entropy'), 0.0436241610738255),
#  ((200, 1, 4, 'entropy'), 0.03709949409780776),
#  ((50, 1, 4, 'gini'), 0.023809523809523808),
#  ((150, 1, 4, 'entropy'), 0.020442930153321975),
#  ((10, 1, 2, 'gini'), 0.0),
#  ((10, 1, 2, 'entropy'), 0.0),
#  ((10, 1, 3, 'entropy'), 0.0),
#  ((10, 1, 4, 'entropy'), 0.0),
#  ((10, 'log2', 2, 'gini'), 0.0),
#  ((50, 1, 2, 'gini'), 0.0),
#  ((50, 1, 2, 'entropy'), 0.0),
#  ((50, 1, 3, 'gini'), 0.0),
#  ((50, 1, 3, 'entropy'), 0.0),
#  ((50, 'log2', 2, 'gini'), 0.0),
#  ((50, 'log2', 2, 'entropy'), 0.0),
#  ((100, 1, 2, 'gini'), 0.0),
#  ((100, 1, 2, 'entropy'), 0.0),
#  ((100, 1, 3, 'gini'), 0.0),
#  ((100, 1, 3, 'entropy'), 0.0),
#  ((100, 'sqrt', 2, 'entropy'), 0.0),
#  ((100, 'log2', 2, 'gini'), 0.0),
#  ((100, 'log2', 2, 'entropy'), 0.0),
#  ((150, 1, 2, 'gini'), 0.0),
#  ((150, 1, 2, 'entropy'), 0.0),
#  ((150, 1, 3, 'gini'), 0.0),
#  ((150, 1, 3, 'entropy'), 0.0),
#  ((150, 'sqrt', 2, 'entropy'), 0.0),
#  ((150, 'log2', 2, 'entropy'), 0.0),
#  ((200, 1, 2, 'gini'), 0.0),
#  ((200, 1, 2, 'entropy'), 0.0),
#  ((200, 1, 3, 'gini'), 0.0),
#  ((200, 1, 3, 'entropy'), 0.0),
#  ((200, 'sqrt', 2, 'entropy'), 0.0),
#  ((200, 'log2', 2, 'entropy'), 0.0)]

# %% [markdown]
# What is the conclusion - did random forest perform better than a single decision tree?
